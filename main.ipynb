# %%
# !pip install -U segmentation-models-pytorch -q

# %%
import os
import cv2
import sys
import glob
import shutil
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import albumentations as A
from dataclasses import dataclass
from tqdm import tqdm,trange,tqdm_notebook
from albumentations.pytorch import ToTensorV2
import segmentation_models_pytorch as smp
from segmentation_models_pytorch import utils

import torch, torchvision
import torch.nn as nn
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models
import torch.nn.functional as F
import torch.optim as optim

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

# %%
@dataclass

class Config:
    maxsize: int = 224
    batch_size: int = 64
    lr: float = 1e-4

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
celeb_path = '/kaggle/input/celeba-dataset/img_align_celeba/img_align_celeba'
segment_path = '/kaggle/input/d/cavidanaslanli/naysunaysu/segmentation_masks'

def get_images(img_path, mask_path):
    img_files = os.listdir(img_path)
    mask_files = os.listdir(mask_path)
    
    img_names = {os.path.splitext(f)[0] for f in img_files}
    mask_names = {os.path.splitext(f)[0] for f in mask_files}
    
    matching_names = img_names.intersection(mask_names)
    matching_pairs = []
    
    for name in matching_names:
        img_file = os.path.join(img_path, name + '.jpg')
        mask_file = os.path.join(mask_path, name + '.bmp')
        if os.path.exists(img_file) and os.path.exists(mask_file):
            matching_pairs.append((img_file, mask_file))
    return matching_pairs

# %%
img_paths = get_images(celeb_path, segment_path)

img_fold = []
mask_fold = []

for i, m in img_paths:
    img_fold.append(i)
    mask_fold.append(m)

# %%
data_transform = A.Compose([
    A.HorizontalFlip(p=0.3),
    A.Resize(256,256),
    A.OneOf(
        [
            A.Sharpen(alpha = (0.1, 0.2), lightness = (0.1, 0.2), p = 0.3),
            A.Blur(blur_limit = [1,3], p=0.3),
            A.GaussNoise(var_limit = (1,5), p = 0.3)
        ]
    ),
    A.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225]),
    ToTensorV2(),
])

# %%
test_transform = A.Compose([
    A.Resize(256,256),
    A.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225]),
    ToTensorV2(),
])

# %%
class Dataset(Dataset):
    def __init__(self, img_paths, mask_paths, input_transform = None):
        
        self.img_paths = img_paths 
        self.mask_paths = mask_paths
        self.transform = input_transform
        
    def __len__(self):
        return len(self.img_paths)
    
    def __getitem__(self, idx):
        img_path = self.img_paths[idx]
        mask_path = self.mask_paths[idx]
        
        image = Image.open(img_path).convert('RGB')
        mask = Image.open(mask_path).convert('L')
        
        mask = np.array(mask)
        binary_mask = np.where(mask == 128, 1, 0)
        
        if self.transform:
            augmented = self.transform(image=np.array(image), mask = binary_mask)
            image = augmented['image']
            mask = augmented['mask']
            
        return image, mask.unsqueeze(0)

# %%
dataset = Dataset(img_fold, mask_fold, input_transform=data_transform)

# %%
def visualize_samples(dataset, num_samples=5):
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=num_samples, shuffle=True)
    images, masks = next(iter(dataloader))
    
    
    images = images.numpy() 
    if images.shape[1] == 3:  
    
        images = images.transpose(0, 2, 3, 1)  
    elif images.shape[1] == 1:  
        images = images.squeeze(1) 
    
    masks = masks.numpy() 
    masks = masks.squeeze(1)
    
    
    plt.figure(figsize=(15, 8))
    for idx in range(num_samples):
        plt.subplot(2, num_samples, idx + 1)
        plt.imshow(images[idx])  
        plt.axis('off')
        plt.title('Image')

        plt.subplot(2, num_samples, idx + 1 + num_samples)
        plt.imshow(masks[idx], cmap='gray')  
        plt.axis('off')
        plt.title('Mask')
    
    plt.tight_layout()
    plt.show()


visualize_samples(dataset, num_samples=10)

# %%
dataloader = DataLoader(dataset, batch_size = Config.batch_size, pin_memory=True, drop_last=True)

# %%
#For training
model = smp.Unet(
    encoder_name = 'resnet34',
    encoder_weights = 'imagenet',
    activation = 'sigmoid',
    classes = 1,
    in_channels = 3
)

# %%
#For generation
model = smp.Unet(
    encoder_name='resnet34',
    encoder_weights=None,  
    activation='sigmoid',
    classes=1,
    in_channels=3
)

# %%
criterion = utils.losses.DiceLoss()
optimizer = optim.AdamW(model.parameters(), lr = Config.lr)

metrics = [
    utils.metrics.Fscore(),
    utils.metrics.IoU()
]

# %%
train_epoch = utils.train.TrainEpoch(
    model,
    loss=criterion,
    metrics = metrics,
    optimizer=optimizer,
    device=device,
    verbose=True
)

# %%
max_score = 0
num_epochs = 10

loss_logs = {"Loss": []}
metric_logs = {"Metrics": []}

for i in range(num_epochs):  
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(dataloader)
    train_loss, train_metric, train_metric_IOU = list(train_logs.values())
    loss_logs["Loss"].append(train_loss)
    metric_logs["Metrics"].append(train_metric_IOU)
    
    print('Train - Epoch {}, Loss: {:.4f}, IOU: {:.4f}'.format(i, train_loss, train_metric_IOU))
    
    if train_metric_IOU > max_score:
        max_score = train_metric_IOU
        torch.save(model.state_dict(), '/kaggle/working/best_model.pth')
# Out:
# Epoch: 0
# train: 100%|██████████| 55/55 [00:47<00:00,  1.15it/s, dice_loss - 0.4566, fscore - 0.767, iou_score - 0.6467]
# Train - Epoch 0, Loss: 0.4566, IOU: 0.6467
#
# Epoch: 1
# train: 100%|██████████| 55/55 [00:47<00:00,  1.16it/s, dice_loss - 0.3377, fscore - 0.9393, iou_score - 0.8857]
# Train - Epoch 1, Loss: 0.3377, IOU: 0.8857
#
# Epoch: 2
# train: 100%|██████████| 55/55 [00:47<00:00,  1.16it/s, dice_loss - 0.2746, fscore - 0.954, iou_score - 0.9122]
# Train - Epoch 2, Loss: 0.2746, IOU: 0.9122
#
# Epoch: 3
# train: 100%|██████████| 55/55 [00:47<00:00,  1.15it/s, dice_loss - 0.2218, fscore - 0.9617, iou_score - 0.9263]
# Train - Epoch 3, Loss: 0.2218, IOU: 0.9263
#
# Epoch: 4
# train: 100%|██████████| 55/55 [00:50<00:00,  1.08it/s, dice_loss - 0.1808, fscore - 0.9654, iou_score - 0.9331]
# Train - Epoch 4, Loss: 0.1808, IOU: 0.9331
#
# Epoch: 5
# train: 100%|██████████| 55/55 [00:47<00:00,  1.17it/s, dice_loss - 0.1494, fscore - 0.9675, iou_score - 0.937]
# Train - Epoch 5, Loss: 0.1494, IOU: 0.9370
#
# Epoch: 6
# train: 100%|██████████| 55/55 [00:47<00:00,  1.17it/s, dice_loss - 0.1253, fscore - 0.9694, iou_score - 0.9406]
# Train - Epoch 6, Loss: 0.1253, IOU: 0.9406
#
# Epoch: 7
# train: 100%|██████████| 55/55 [00:48<00:00,  1.15it/s, dice_loss - 0.1075, fscore - 0.9697, iou_score - 0.9413]
# Train - Epoch 7, Loss: 0.1075, IOU: 0.9413
#
# Epoch: 8
# train: 100%|██████████| 55/55 [00:47<00:00,  1.16it/s, dice_loss - 0.09312, fscore - 0.971, iou_score - 0.9436]
# Train - Epoch 8, Loss: 0.0931, IOU: 0.9436
#
# Epoch: 9
# train: 100%|██████████| 55/55 [00:47<00:00,  1.16it/s, dice_loss - 0.08171, fscore - 0.9722, iou_score - 0.9458]
# Train - Epoch 9, Loss: 0.0817, IOU: 0.9458

# %%
def denormalize(image):
    mean_tensor = torch.tensor(mean, device=image.device).view(1, 3, 1, 1)
    std_tensor = torch.tensor(std, device=image.device).view(1, 3, 1, 1)
    return image * std_tensor + mean_tensor

# %%
def visualize_predictions(image, mask, prediction):
    image = denormalize(image).squeeze(0)
    
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    
    axes[0].imshow(image.permute(1, 2, 0).cpu().numpy())
    axes[0].set_title('Image')
    
    axes[1].imshow(mask.squeeze(0).cpu().numpy(), cmap='gray')
    axes[1].set_title('Ground Truth Mask')
    
    axes[2].imshow(prediction.squeeze(0).cpu().numpy(), cmap='gray')
    axes[2].set_title('Predicted Mask')
    
    for ax in axes:
        ax.axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
model.load_state_dict(torch.load('/kaggle/input/facebest/facebest.pth'))
model.to(device)
model.eval()

# %%
for images, masks in dataloader:
    images = images.to(device)
    masks = masks.to(device)
    
    with torch.no_grad():
        predictions = model(images)
        predictions = (predictions > 0.5).float()
    
    visualize_predictions(images[62], masks[62], predictions[62])
    break

# %%
def generation(image_path, model):
    image = Image.open(image_path).convert('RGB')
    transform = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
    input_tensor = transform(image).unsqueeze(0)
    model.eval()
    device = next(model.parameters()).device 
    input_tensor = input_tensor.to(device)
    
    with torch.no_grad():
        predictions = model(input_tensor)
        predictions = (predictions > 0.5).float()
        
    input_image = denormalize(input_tensor).squeeze(0).permute(1, 2, 0).cpu().numpy()
    predicted_mask = predictions.squeeze(0).squeeze(0).cpu().numpy() 
    
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    
    axes[0].imshow(input_image)
    axes[0].set_title('Input Image')
    axes[0].axis('off')
    
    axes[1].imshow(predicted_mask, cmap='gray')
    axes[1].set_title('Predicted Mask')
    axes[1].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
test_img_path = '/kaggle/input/uaremysunshine/images.jpeg'

# %%
generation(test_img_path, model)
